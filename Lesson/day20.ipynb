# %% [markdown]
# # Introduction to Pandas - Day 20

# %% [markdown]
# Congratulations! You've learned enough Python to start using pandas.Pandas is the most popular Python library for data analysis. It makes working with tabular data fast and fun.Think of pandas like a supercharged spreadsheet inside Python. Everything you did with loops, lists, and dicts before, pandas does in one line.

# %% [markdown]
# ## 1. Installing PandasBefore you can use pandas, you need to install it.

# %%
# Run this in your terminal:# pip install pandas# If you want NumPy too (pandas depends on it):# pip install numpy pandas

# %% [markdown]
# ## 2. What is a DataFrame?A DataFrame is a 2D table with rows and columns. It's the main object in pandas.Think of it like a spreadsheet tab. Each column has a name, each row has an index (like row numbers), and every cell holds a value.

# %%
# First, import pandas (convention: import pandas as pd)try:    import pandas as pdexcept ImportError:    print("pandas not installed. Run: pip install pandas")    exit()# Create a DataFrame from a dictionarydata = {    'item': ['croissant', 'muffin', 'bagel', 'cookie'],    'price': [3.50, 2.00, 2.75, 1.50],    'sold': [12, 8, 15, 23],}df = pd.DataFrame(data)print(df)

# %% [markdown]
# ## 3. Basic DataFrame OperationsPandas makes common operations incredibly simple.

# %%
# View the first few rowsprint(df.head())print()# Get basic statisticsprint(df.describe())print()# Select a column (returns a Series - like a list with labels)print(df['price'])print()# Select multiple columnsprint(df[['item', 'sold']])

# %% [markdown]
# ## 4. Filtering with PandasRemember our list comprehensions with conditions? Pandas does this even more elegantly.

# %%
# Filter: items that sold more than 10popular = df[df['sold'] > 10]print(popular)print()# Multiple conditionspopularCheap = df[(df['sold'] > 10) & (df['price'] < 3.00)]print(popularCheap)print()# Note: use & instead of 'and', | instead of 'or'# Put each condition in parentheses!

# %% [markdown]
# ## 5. Adding and Modifying ColumnsPandas makes creating new columns trivial.

# %%
# Add a 'revenue' column (vectorized - no loop!)df['revenue'] = df['price'] * df['sold']print(df)print()# Add a discounted price columndf['discounted_price'] = df['price'] * 0.9print(df)print()# Rename a columndf = df.rename(columns={'sold': 'quantity_sold'})print(df)

# %% [markdown]
# ## 6. Reading Data with PandasThis is where pandas REALLY shines. One line to read a file.

# %%
# Read CSV - one line instead of 5+ with csv module!# df = pd.read_csv('sales.csv')# Read JSON# df = pd.read_json('bakery.json')# Read Excel (requires openpyxl)# df = pd.read_excel('bakery.xlsx')# Read from a URL# df = pd.read_csv('https://example.com/data.csv')print('One line to read any data format!')

# %%
# Let's see what pandas can do that took us 10+ lines yesterdaywith open("pipeline_sales.csv", "w") as f:    f.write("item,quantity,price\n")    f.write("croissant,12,3.50\n")    f.write("muffin,8,2.00\n")    f.write("bagel,15,2.75\n")    f.write("cookie,23,1.50\n")df = pd.read_csv('pipeline_sales.csv')df['revenue'] = df['quantity'] * df['price']print(df)print()print(f"Total revenue: ${df['revenue'].sum():.2f}")print(f"Average price: ${df['price'].mean():.2f}")print(f"Best seller: {df.loc[df['quantity'].idxmax(), 'item']}")

# %% [markdown]
# ## 7. Grouping and AggregatingPandas can group data and calculate summaries - like pivot tables in Excel.

# %%
# Create some sample data with categoriesdata = {    'category': ['pastry', 'pastry', 'bread', 'bread', 'drink'],    'item': ['croissant', 'muffin', 'bagel', 'sourdough', 'coffee'],    'price': [3.50, 2.00, 2.75, 5.00, 2.50],    'sold': [12, 8, 15, 6, 20],}df = pd.DataFrame(data)# Group by category and calculate average pricecategorySummary = df.groupby('category')['price'].mean()print(categorySummary)print()# Multiple aggregationssummary = df.groupby('category').agg({    'price': 'mean',    'sold': 'sum',})print(summary)

# %% [markdown]
# ## 8. What's Next?You're now ready to dive deeper into pandas and other libraries:1. **Pandas in-depth**: `merge()`, `concat()`, handling missing data, time series.2. **NumPy**: Numerical computing with arrays (faster than lists).3. **Matplotlib / Seaborn**: Data visualization (charts and graphs).4. **Plotly**: Interactive charts.5. **Requests + BeautifulSoup**: Web scraping.6. **APIs**: Fetching data from web services.7. **Scikit-learn**: Machine learning (after you're comfortable with pandas).You have a solid foundation. Everything you learned from day1 to day19 is exactly what you needed to get here.

# %%
# Final messageprint('Congrats on reaching the end of the beginner curriculum!')print('You now know enough Python to start working with pandas.')print('The bakery assignments taught you:')print('  - Variables, functions, conditionals')print('  - Loops, error handling, file I/O')print('  - Classes, inheritance, modules')print('  - List comprehensions, lambdas, advanced functions')print('  - CSV, JSON, datetime, data pipelines')print('  - Vectorized thinking and pandas basics')print()print('Now go analyze some data!')

# %% [markdown]
# ## Summary- **pandas** is the #1 Python library for data analysis.- **DataFrame** = a table (like a spreadsheet tab).- **Series** = a single column (like a list with labels).- `pd.read_csv()` / `pd.read_json()` / `pd.read_excel()` - read data in one line.- `df['column']` - select a column.- `df[condition]` - filter rows.- `df['new'] = ...` - create a new column (vectorized!).- `df.groupby()` - group and aggregate.- `df.describe()` - quick statistics.- Everything you learned from day1-19 was building toward this!
